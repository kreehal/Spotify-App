# %% [markdown]
# # **Menon Labs: Spotify Data Analysis - Cluster Labeling**

# %% [markdown]
# ## **Collaborators**
# - Shubhum Agrawal
# - Ashna Sood
# - Shania Sinha
# - Sergio Vazquez
# - Rohil Khatkhate
# - Kerrn Reehal

# %% [markdown]
# ## **Imports**

# %%
# %matplotlib inline

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os 

import seaborn as sns
sns.set()
sns.set_context('talk')

import warnings
warnings.filterwarnings('ignore')

import patsy
import statsmodels.api as sm
import scipy.stats as stats

from sklearn.metrics import classification_report, precision_recall_fscore_support, mean_absolute_error, mean_squared_error
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE

from sklearn import metrics

from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## **Labeling Clusters**

# %%
# combine the individual cluster csv files into one big dataframe
basepath = '/content/drive/MyDrive/Clubs Activities/Ethi_SpotifyProject/clustering results/new_data_30/'
data = pd.read_csv(basepath+'songs_0.csv')
data['cluster'] = 0
for i in range(1, 30):
  df = pd.read_csv(basepath+f'songs_{i}.csv')
  df['cluster'] = i
  data = data.append(df)
data
# Out:
#                           id                         name  ...    tempo  cluster
# 0     35mvY5S1H3J2QZyna3TFe0                    positions  ...  144.015        0
# 1     6Hj9jySrnFppAI0sEMCZpJ                      Robbery  ...  159.966        0
# 2     2xLMifQCjDGFmkHkpNLD9h                   SICKO MODE  ...  155.008        0
# 3     27X3qzgB0Show6qfw5wNOK            Esquema Preferido  ...  159.934        0
# 4     2Y0wPrPQBrGhoLn14xRYCG  Come & Go (with Marshmello)  ...  144.991        0
# ...                      ...                          ...  ...      ...      ...
# 5510  4qZq5qn0CSA6YF96OM5XVZ    Manifest- Manifest (2004)  ...  212.980       29
# 5511  6T0aBJyFi7U3zHuaYSMWIP             Bach Jao Mundeyo  ...  183.985       29
# 5512  2n8nDfBot4MddUcUKoAqGz                    Horseface  ...  188.499       29
# 5513  55PHPSzHvd0AzuMTFDracv          Nekal mani gredzenā  ...  199.410       29
# 5514  5mWRy3TEbMDAeXN8KXNcUg                Vertu nú sæll  ...  205.937       29
#
# [400497 rows x 13 columns]

# %%
# all 30 cluster's associated emotion label -- multiple clusters with similar moods have the same label to further simplify and group the songs by emotion
labels = [
    'Energetic', 'Chill', 'Vulnerable', 'Chill', 'Soothing',
    'Chill', 'Soothing', 'Wistful', 'Energetic', 'Calm',
    'Vulnerable', 'Vulnerable', 'Sentimental', 'Powerful', 'Energetic',
    'Vulnerable', 'Powerful', 'Energetic', 'Energetic', 'Sentimental',
    'Chill', 'Soothing', 'Calm', 'Energetic', 'Wistful',
    'Upbeat', 'Energetic', 'Vulnerable', 'Upbeat', 'Powerful'
]
pd.unique(labels)
# Out:
# array(['Energetic', 'Chill', 'Vulnerable', 'Soothing', 'Wistful', 'Calm',
#        'Sentimental', 'Powerful', 'Upbeat'], dtype=object)

# %%
# include Emotion label in dataframe
data['emotion'] = [labels[c] for c in data['cluster']]
data
# Out:
#                           id                         name  ... cluster    emotion
# 0     35mvY5S1H3J2QZyna3TFe0                    positions  ...       0  Energetic
# 1     6Hj9jySrnFppAI0sEMCZpJ                      Robbery  ...       0  Energetic
# 2     2xLMifQCjDGFmkHkpNLD9h                   SICKO MODE  ...       0  Energetic
# 3     27X3qzgB0Show6qfw5wNOK            Esquema Preferido  ...       0  Energetic
# 4     2Y0wPrPQBrGhoLn14xRYCG  Come & Go (with Marshmello)  ...       0  Energetic
# ...                      ...                          ...  ...     ...        ...
# 5510  4qZq5qn0CSA6YF96OM5XVZ    Manifest- Manifest (2004)  ...      29   Powerful
# 5511  6T0aBJyFi7U3zHuaYSMWIP             Bach Jao Mundeyo  ...      29   Powerful
# 5512  2n8nDfBot4MddUcUKoAqGz                    Horseface  ...      29   Powerful
# 5513  55PHPSzHvd0AzuMTFDracv          Nekal mani gredzenā  ...      29   Powerful
# 5514  5mWRy3TEbMDAeXN8KXNcUg                Vertu nú sæll  ...      29   Powerful
#
# [400497 rows x 14 columns]

# %%
data.sample(frac=1)
# Out:
#                            id  ...     emotion
# 3490   1NOkswJTI2ap7QNhTi2kfi  ...     Wistful
# 12472  0fMRGuLoCCtv8CNklMGxaB  ...       Chill
# 6622   3hE8uQOjzxvIBXPH3mIS2V  ...   Energetic
# 6786   0XFYhlNH5OEQnYg9Oj21U5  ...  Vulnerable
# 3328   40Yek1A84Gh1I1X5bo634P  ...   Energetic
# ...                       ...  ...         ...
# 3818   0eafUurZ4awQ3ZAIvHr608  ...  Vulnerable
# 18161  7hzLyLUhgMOEyjrmgkLYt7  ...   Energetic
# 4760   5r1P52qgqAGKnfYpPGFisR  ...        Calm
# 910    73yB2HMz9zu0VcueZ4P1UU  ...  Vulnerable
# 113    5adBd6nubkd4fUeRDAL8VP  ...    Powerful
#
# [400497 rows x 14 columns]

# %%
# make the song ID the index of the dataframe
data = data.set_index('id')
data
# Out:
#                                                name  ...    emotion
# id                                                   ...
# 35mvY5S1H3J2QZyna3TFe0                    positions  ...  Energetic
# 6Hj9jySrnFppAI0sEMCZpJ                      Robbery  ...  Energetic
# 2xLMifQCjDGFmkHkpNLD9h                   SICKO MODE  ...  Energetic
# 27X3qzgB0Show6qfw5wNOK            Esquema Preferido  ...  Energetic
# 2Y0wPrPQBrGhoLn14xRYCG  Come & Go (with Marshmello)  ...  Energetic
# ...                                             ...  ...        ...
# 4qZq5qn0CSA6YF96OM5XVZ    Manifest- Manifest (2004)  ...   Powerful
# 6T0aBJyFi7U3zHuaYSMWIP             Bach Jao Mundeyo  ...   Powerful
# 2n8nDfBot4MddUcUKoAqGz                    Horseface  ...   Powerful
# 55PHPSzHvd0AzuMTFDracv          Nekal mani gredzenā  ...   Powerful
# 5mWRy3TEbMDAeXN8KXNcUg                Vertu nú sæll  ...   Powerful
#
# [400497 rows x 13 columns]

# %%
# save the final emotion labeled tracks as a CSV file
data.to_csv(basepath+'final_labels.csv')

# %% [markdown]
# ## **Save Metadata of Songs**

# %%
# save metadata for each track 
important_data = data[['name', 'artists', 'emotion']]
important_data
# Out:
#                                                name  ...    emotion
# id                                                   ...
# 35mvY5S1H3J2QZyna3TFe0                    positions  ...  Energetic
# 6Hj9jySrnFppAI0sEMCZpJ                      Robbery  ...  Energetic
# 2xLMifQCjDGFmkHkpNLD9h                   SICKO MODE  ...  Energetic
# 27X3qzgB0Show6qfw5wNOK            Esquema Preferido  ...  Energetic
# 2Y0wPrPQBrGhoLn14xRYCG  Come & Go (with Marshmello)  ...  Energetic
# ...                                             ...  ...        ...
# 4qZq5qn0CSA6YF96OM5XVZ    Manifest- Manifest (2004)  ...   Powerful
# 6T0aBJyFi7U3zHuaYSMWIP             Bach Jao Mundeyo  ...   Powerful
# 2n8nDfBot4MddUcUKoAqGz                    Horseface  ...   Powerful
# 55PHPSzHvd0AzuMTFDracv          Nekal mani gredzenā  ...   Powerful
# 5mWRy3TEbMDAeXN8KXNcUg                Vertu nú sæll  ...   Powerful
#
# [400497 rows x 3 columns]

# %%
# extract primary artist from songs with multiple artists
def get_primary_artist(list_str):
  list_str = list_str.strip('[]')
  artist_strs = list_str.split(', ')
  return artist_strs[0].strip("'")

# add primary artist for each track in the df
important_data['primary_artist'] = [get_primary_artist(a) for a in important_data['artists']]
important_data
# Out:
#                                                name  ...    primary_artist
# id                                                   ...
# 35mvY5S1H3J2QZyna3TFe0                    positions  ...     Ariana Grande
# 6Hj9jySrnFppAI0sEMCZpJ                      Robbery  ...        Juice WRLD
# 2xLMifQCjDGFmkHkpNLD9h                   SICKO MODE  ...      Travis Scott
# 27X3qzgB0Show6qfw5wNOK            Esquema Preferido  ...           DJ Ivis
# 2Y0wPrPQBrGhoLn14xRYCG  Come & Go (with Marshmello)  ...        Juice WRLD
# ...                                             ...  ...               ...
# 4qZq5qn0CSA6YF96OM5XVZ    Manifest- Manifest (2004)  ...             Abuse
# 6T0aBJyFi7U3zHuaYSMWIP             Bach Jao Mundeyo  ...  Sardool Sikander
# 2n8nDfBot4MddUcUKoAqGz                    Horseface  ...            Yea(H)
# 55PHPSzHvd0AzuMTFDracv          Nekal mani gredzenā  ...    Raimonds Pauls
# 5mWRy3TEbMDAeXN8KXNcUg                Vertu nú sæll  ...   Ómar Ragnarsson
#
# [400497 rows x 4 columns]

# %%
important_data.rename(columns={'name': 'trackName', 'primary_artist': 'artistName'}, inplace=True)
important_data
# Out:
#                                           trackName  ...        artistName
# id                                                   ...
# 35mvY5S1H3J2QZyna3TFe0                    positions  ...     Ariana Grande
# 6Hj9jySrnFppAI0sEMCZpJ                      Robbery  ...        Juice WRLD
# 2xLMifQCjDGFmkHkpNLD9h                   SICKO MODE  ...      Travis Scott
# 27X3qzgB0Show6qfw5wNOK            Esquema Preferido  ...           DJ Ivis
# 2Y0wPrPQBrGhoLn14xRYCG  Come & Go (with Marshmello)  ...        Juice WRLD
# ...                                             ...  ...               ...
# 4qZq5qn0CSA6YF96OM5XVZ    Manifest- Manifest (2004)  ...             Abuse
# 6T0aBJyFi7U3zHuaYSMWIP             Bach Jao Mundeyo  ...  Sardool Sikander
# 2n8nDfBot4MddUcUKoAqGz                    Horseface  ...            Yea(H)
# 55PHPSzHvd0AzuMTFDracv          Nekal mani gredzenā  ...    Raimonds Pauls
# 5mWRy3TEbMDAeXN8KXNcUg                Vertu nú sæll  ...   Ómar Ragnarsson
#
# [400497 rows x 3 columns]

# %%
# reorder columns for proper format for json files
important_data = important_data[['trackName', 'artistName', 'emotion']]
important_data
# Out:
#                                           trackName  ...    emotion
# id                                                   ...
# 35mvY5S1H3J2QZyna3TFe0                    positions  ...  Energetic
# 6Hj9jySrnFppAI0sEMCZpJ                      Robbery  ...  Energetic
# 2xLMifQCjDGFmkHkpNLD9h                   SICKO MODE  ...  Energetic
# 27X3qzgB0Show6qfw5wNOK            Esquema Preferido  ...  Energetic
# 2Y0wPrPQBrGhoLn14xRYCG  Come & Go (with Marshmello)  ...  Energetic
# ...                                             ...  ...        ...
# 4qZq5qn0CSA6YF96OM5XVZ    Manifest- Manifest (2004)  ...   Powerful
# 6T0aBJyFi7U3zHuaYSMWIP             Bach Jao Mundeyo  ...   Powerful
# 2n8nDfBot4MddUcUKoAqGz                    Horseface  ...   Powerful
# 55PHPSzHvd0AzuMTFDracv          Nekal mani gredzenā  ...   Powerful
# 5mWRy3TEbMDAeXN8KXNcUg                Vertu nú sæll  ...   Powerful
#
# [400497 rows x 3 columns]

# %%
# sort df by track and artist
important_data.sort_values(by=['trackName', 'artistName'], inplace=True)
important_data
# Out:
#                                                                 trackName  ...    emotion
# id                                                                         ...
# 1A05ibu1DXGIt0F62NG7xU                                                  !  ...  Energetic
# 4AFCrbzvR3vLfekhABLjDU                     ! (The Song Formerly Known As)  ...  Energetic
# 4v1IBp3Y3rpkWmWzIlkYju                                     !!De Repente!!  ...  Energetic
# 7y07vRzFxldnZ4ZsXyWaWB                                        !H.a.p.p.y!  ...      Chill
# 0fROT4kK5oTm8xO8PX6EJF                                     !I'll Be Back!  ...  Energetic
# ...                                                                   ...  ...        ...
# 5vubdGDI1f6Dgq8l9kYOXV                            행복했던 날들이었다 days gone by  ...  Energetic
# 3Gpdzw72aBVJSrm5J1leVK  헤어지지 못하는 여자, 떠나가지 못하는 남자 Can't Breakup Girl, C...  ...  Energetic
# 6KrJn7TLGbkXwbU8GAS5Sk                                 헤픈엔딩 Happen Ending  ...  Energetic
# 2p5DfmIUTLH79elmaSCCR5                화려하지 않은 고백 Confession Is Not Flashy  ...      Chill
# 4iH7negBYMfj2z0wDNmgdx                                                NaN  ...   Powerful
#
# [400497 rows x 3 columns]

# %%
# export metadata associated with songs as a JSON file 
import json
result = important_data.to_json(orient='records')
parsed = json.loads(result)
json.dump(parsed, open(basepath+'song_info.json', 'w'), indent=4)
